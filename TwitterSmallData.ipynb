# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "Philadelphia 76ers OR @sixers OR 76ers -filter:retweets"

with open('atlantic_sTwitterData.txt', 'w') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "Toronto Raptors OR #Raptors OR @Raptors -filter:retweets"

with open('atlantic_sTwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "Boston Celtics OR #celtics OR @celtics -filter:retweets"

with open('atlantic_sTwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "Brooklyn Nets OR #nets OR @BrooklynNets -filter:retweets"

with open('atlantic_sTwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "New York Knicks OR #knicks OR @nyknicks -filter:retweets"

with open('atlantic_sTwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "Golden State Warriors OR @warriors OR The Dubs OR The Warriors OR State Warriors OR Golden State OR Warriors OR GSW -filter:retweets"

with open('pacific_stwitterData.txt', 'w') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "lakers OR los angeles lakers OR #lakers -filter:retweets"

with open('pacific_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         
    
        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "los angeles clippers OR @LAClippers OR #clippers -filter:retweets"

with open('pacific_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         
    
        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "phoenix suns OR @Suns -filter:retweets"

with open('pacific_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         
    
        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0
tweetChecklist = []
new_search = "sacramento kings OR #kings OR @SacramentoKings -filter:retweets"

with open('pacific_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         
    
        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
            if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Houston Rockets OR Rockets OR @HoustonRockets -filter:retweets"

with open('southwest_stwitterData.txt', 'w') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Rate limit reached. Sleeping for: 211
# Downloaded 43 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "#mavs OR Dallas Mavericks OR @dallasmavs -filter:retweets"

with open('southwest_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 11 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Memphis Grizzlies OR #grizzlies OR @memgrizz OR @GrizzliesPR -filter:retweets"

with open('southwest_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 16 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "New Orleans Pelicans OR #pelicans OR @PelicansNBA -filter:retweets"

with open('southwest_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 25 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "San Antonio Spurs OR #spurs -filter:retweets"

with open('southwest_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(500) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 145 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Denver Nuggets OR #nuggets OR @nuggets -filter:retweets"

with open('northwest_stwitterData.txt', 'w') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 75 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Minnesota Timberwolves OR #twolves OR @Timberwolves -filter:retweets"

with open('northwest_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(200) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 198 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Oklahoma City Thunder OR #okc OR @okcthunder -filter:retweets"

with open('northwest_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 99 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Portland Trail Blazers OR #blazers OR @trailblazers -filter:retweets"

with open('northwest_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 82 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Utah Jazz OR #utahjazz OR @utahjazz -filter:retweets"

with open('northwest_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 95 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Atlanta Hawks OR #atlantahawks OR @ATLHawks -filter:retweets"

with open('southeast_stwitterData.txt', 'w') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 99 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Charlotte Hornets OR @hornets OR @HornetsPR -filter:retweets"

with open('southeast_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 97 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Miami Heat OR #heat OR @MiamiHEAT -filter:retweets"

with open('southeast_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Orlando Magic OR @OrlandoMagic -filter:retweets"

with open('southeast_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 99 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Washington Wizards OR #wizards OR @WashWizards -filter:retweets"

with open('southeast_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 97 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Chicago Bulls OR #bulls OR @chicagobulls -filter:retweets"

with open('central_stwitterData.txt', 'w') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 97 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Cleveland Cavaliers OR #cavaliers OR @cavs -filter:retweets"

with open('central_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 98 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Detroit Pistons OR #pistons OR @DetroitPistons -filter:retweets"

with open('central_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 98 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Indiana Pacers OR #pacers OR @pacers -filter:retweets"

with open('central_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "Milwaukee Bucks OR #bucks OR @bucks -filter:retweets"

with open('central_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 59 tweets

# %%
import tweepy
consumer_key = "JlWj4jM87fZwG29kJVh2sFWbO"
consumer_secret = "tdLp4k7maEvGzsYbGrF41JP8Fvjggn8GmByAZfFeAup2wBMQVM"
access_token = "1102467059496206336-S5T0bC4yRn3tvSAOwSB9bzISJj73Px"
access_token_secret = "0hzO9aTsjOJl5vi3iGCGM60TIPWmu3vuMQSlRnRyaJQvT"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True) 
text = ""
tweetCount = 0

new_search = "NBA OR #nba -filter:retweets"

with open('nba_stwitterData.txt', 'a+') as f:

    #Tell the Cursor method that we want to use the Search API (api.search)
    #Also tell Cursor our query, and the maximum number of tweets to return
    for tweet in tweepy.Cursor(api.search,q=new_search,lang="en",since='2019-01-01').items(100) :         

        #Verify the tweet has place info before writing (It should, if it got past our place filter)
        if tweet.text is not None:
             if tweet.text not in tweetChecklist:
                # Store it, so that on further times with the same text, 
                # it didn't reach this code
                tweet.text = tweet.text.replace('\n', ' ')
                tweetChecklist.append(tweet.text);
            #Write the JSON format to the text file, and add one to the number of tweets we've collected
                f.write(tweet.text)
                f.write("\n")
                tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 100 tweets
