# %%
import requests
import argparse
import time
import json
import gzip
import csv
import codecs
import io

from bs4 import BeautifulSoup
domain = "nba.com"
search_keywords = ["celtics","nets","knicks","raptors","76ers"]
index_list = ["2019-04","2019-09","2019-13"]
def search_domain(domain):

    record_list = []
    
    print("[*] Trying target domain: %s" % domain)
    
    for index in index_list:
        
        print("[*] Trying index %s" % index)
        
        cc_url  = "http://index.commoncrawl.org/CC-MAIN-%s-index?" % index
        cc_url += "url=%s&matchType=domain&output=json" % domain
        
        response = requests.get(cc_url)
        
        if response.status_code == 200:
            
            records = response.content.splitlines()
            
            for record in records:
                record_list.append(json.loads(record))
            
            print("[*] Added %d results." % len(records))
            
    
    print("[*] Found a total of %d hits." % len(record_list))
    
    return record_list  

def download_page(record):

    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1

    # We'll get the file via HTTPS so we don't need to worry about S3 credentials
    # Getting the file on S3 is equivalent however - you can request a Range
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    
    # We can then use the Range header to ask for just this set of bytes
    resp = requests.get(prefix + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
    # The page is stored compressed (gzip) to save space
    # We can extract it using the GZIP library
    raw_data = io.BytesIO(resp.content)
    f = gzip.GzipFile(fileobj=raw_data)
    
    # What we have now is just the WARC response, formatted:
    data = f.read()

    response = ""
    fdg = []
    #print(len(data))
    if len(data):
            fdg = data.decode('UTF-8').strip().split("\r\n\r\n")
            if(len(fdg)>2):
                response = fdg[2]
                #print(fdg[0])
                #print(response)
    return response
count=0
weburlTest=[]
category = "news"
keywordtest = "/"+category+"/"
record_list = search_domain(domain)
index = open('atlantic_scrawlData.txt', 'w')
for record in record_list[:9000]:
    for idx in range(0,len(search_keywords)):
        #if(keywordtest.lower() in record['url']): 
            search_keyword = search_keywords[idx]
            keyword = "/"+search_keyword+"/"
            #print(keyword)
            if(keywordtest.lower() in record['url']):
                if(keyword.lower() in record['url']):
                    print(record['url'])
                    count+=1
                    print(count)
                    html_content = download_page(record)
                    soup = BeautifulSoup(html_content)
                    for p in soup.find_all("p", text=True):
                        rete = p.get_text()
                        rete = rete.replace('\n', '')
                        rete = rete.replace('\r\n', '')
                        rete = rete.replace('\\n','')
                        rete = rete.replace('\t','')
                        #print(rete)
                        index.write(rete)
                    index.write("\n")
# Out:
# [*] Trying target domain: nba.com
# [*] Trying index 2019-04
# [*] Added 13445 results.
# [*] Trying index 2019-09
# [*] Added 14007 results.
# [*] Trying index 2019-13
# [*] Added 14261 results.
# [*] Found a total of 41713 hits.
# https://www.nba.com/celtics/news/post-ups
# 1
# https://www.nba.com/celtics/news/post-ups-20181105
# 2
# https://www.nba.com/celtics/news/post-ups-20181108
# 3
# https://www.nba.com/celtics/news/post-ups-20181109
# 4
# https://www.nba.com/celtics/news/post-ups-20190109
# 5
# https://www.nba.com/celtics/news/post-ups-20190110
# 6
# https://www.nba.com/celtics/news/press_release/celtics-complete-trade-brooklyn-nets
# 66
# https://www.nba.com/celtics/news/sidebar/post-110918-celtics-are-paying-with-fire-far-too-often-on-this-road-trip
# 67
# https://www.nba.com/celtics/news/sidebar/post-121418-/celtics-offense-keeps-thriving-thanks-great-defensive-habits
# 68
# https://www.nba.com/celtics/news/sidebar/prac-031218-theis-season-ending-injury-forces-celtics-make-adjustments
# 69
# https://www.nba.com/celtics/news/sidebar/prac-101418-celtics-drawing-inspiration-red-sox-title-contending-traits
# 70
# https://www.nba.com/celtics/news/sidebar/prac-110718-patience-is-a-virtue-so-have-some-with-these-celtics
# 71
# https://www.nba.com/celtics/news/sidebar/prac-120518-celtics-look-maintain-positive-momentum-rematch-vs-knicks
# 72
# https://www.nba.com/celtics/news/sidebar/shoot-011219-celtics-vividly-remember-orlandos-frontline-dominance-back-in-october
# 73
# https://www.nba.com/celtics/news/sidebar/shoot-011419-celts-nets-exchange-roles-on-health-front-for-tonights-rematch
# 74
# https://www.nba.com/celtics/news/sidebar/shoot-110518-celtics-say-millsap-has-been-secret-to-denvers-early-success
# 75
# https://www.nba.com/celtics/news/sidebar/shoot-110718-rozier-shoots-down-rumors-im-happy-to-be-in-this-position
# 76
# https://www.nba.com/celtics/news/sidebar/shoot-visitor-111618-raptors-aim-end-short-skid-boston-friday-night
# 77
# http://www.nba.com/celtics/news/sidebar/summer-062217-stevens-ainge-enthralled-tatums-potential
# 78
# https://www.nba.com/celtics/news/sidebar/summer-062217-stevens-ainge-enthralled-tatums-potential
# 79
# https://www.nba.com/celtics/news/sidebar/summer-071118-aron-baynes-top-performances-as-celtic
# 80
# http://www.nba.com/celtics/news/sidebar/summer-072716-gerald-green-returns-to-where-it-all-started
# 81
# https://www.nba.com/celtics/news/sidebar/summer-072716-gerald-green-returns-to-where-it-all-started
# 82
# https://www.nba.com/celtics/news/sidebar/summer-081418-theis-nearing-return-to-live-action-added-new-skill-during-rehab
# 83
# https://www.nba.com/celtics/news/sidebar/summer-082318-five-facts-wanamaker-williams
# 84
# https://www.nba.com/celtics/news/sidebar/summer-090518-unfinished-business-has-left-baynes-yearning-more
# 85
# http://www.nba.com/celtics/news/sidebar/top-prospects-eye-boston-landing-spot
# 86
# https://www.nba.com/celtics/news/sidebar/top-prospects-eye-boston-landing-spot
# 87
# https://www.nba.com/celtics/news/twhs-20180621-draft
# 88

# %%
import requests
import argparse
import time
import json
import gzip
import csv
import codecs
import io

from bs4 import BeautifulSoup
domain = "nba.com"
search_keywords = ["celtics","nets","knicks","raptors","76ers"]
index_list = ["2019-04","2019-09","2019-13"]
def search_domain(domain):

    record_list = []
    
    print("[*] Trying target domain: %s" % domain)
    
    for index in index_list:
        
        print("[*] Trying index %s" % index)
        
        cc_url  = "http://index.commoncrawl.org/CC-MAIN-%s-index?" % index
        cc_url += "url=%s&matchType=domain&output=json" % domain
        
        response = requests.get(cc_url)
        
        if response.status_code == 200:
            
            records = response.content.splitlines()
            
            for record in records:
                record_list.append(json.loads(record))
            
            print("[*] Added %d results." % len(records))
            
    
    print("[*] Found a total of %d hits." % len(record_list))
    
    return record_list  

def download_page(record):

    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1

    # We'll get the file via HTTPS so we don't need to worry about S3 credentials
    # Getting the file on S3 is equivalent however - you can request a Range
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    
    # We can then use the Range header to ask for just this set of bytes
    resp = requests.get(prefix + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
    # The page is stored compressed (gzip) to save space
    # We can extract it using the GZIP library
    raw_data = io.BytesIO(resp.content)
    f = gzip.GzipFile(fileobj=raw_data)
    
    # What we have now is just the WARC response, formatted:
    data = f.read()

    response = ""
    fdg = []
    #print(len(data))
    if len(data):
            htmlData = data.decode('UTF-8').strip().split("\r\n\r\n")
            if(len(htmlData)>2):
                response = htmlData[2]
    return response
count=0
weburlTest=[]
category = "amp"
keywordtest = "/"+category+"/"
record_list = search_domain(domain)
index = open('atlantic_scrdawlData.txt', 'a+')
for record in record_list[:5000]:
    for idx in range(0,len(search_keywords)):
        #if(keywordtest.lower() in record['url']): 
            search_keyword = search_keywords[idx]
            keyword = "/"+search_keyword+"/"
            #print(keyword)
            if(keywordtest.lower() in record['url']):
                if(keyword.lower() in record['url']):
                    print(record['url'])
                    count+=1
                    print(count)
                    html_content = download_page(record)
                    soup = BeautifulSoup(html_content)
                    for p in soup.find_all("p", text=True):
                        rete = p.get_text()
                        rete = rete.replace('\n', '')
                        rete = rete.replace('\r\n', '')
                        rete = rete.replace('\\n','')
                        rete = rete.replace('\t','')
                        #print(rete)
                        index.write(rete)
                    index.write("\n")
# Out:
# [*] Trying target domain: nba.com
# [*] Trying index 2019-04
# [*] Added 13445 results.
# [*] Trying index 2019-09
# [*] Added 14007 results.
# [*] Trying index 2019-13
# [*] Added 14261 results.
# [*] Found a total of 41713 hits.
# https://www.nba.com/amp/celtics/video/originals/ainge-trade-deadline-presser-020918
# 1
# https://www.nba.com/amp/celtics/video/originals/celticsdaily-020918
# 2
# https://www.nba.com/amp/celtics/video/originals/film-study-baynes-verticality-121917
# 3
# https://www.nba.com/amp/celtics/video/team/pregame-interview-020818
# 4
# https://www.nba.com/amp/celtics/video/team/pregame-interview-030718
# 5
# https://www.nba.com/amp/celtics/video/team/pregame-interview-030818
# 6
# https://www.nba.com/amp/celtics/video/teams/celtics/2018/02/09/1917205/1518204570875-postgamereport020818atwasver2-1917205
# 7
# https://www.nba.com/amp/celtics/video/wsc/teams/03d339fe-ca2f-6e0d-0588-11e4b8bea365
# 8
# https://www.nba.com/amp/celtics/video/wsc/teams/30485d37-1f5a-2f1d-f2c6-1a01ee2a7670
# 9
# https://www.nba.com/amp/celtics/video/wsc/teams/345a8d2b-d0e1-9ffb-c7d1-c49e4957fccd
# 10
# https://www.nba.com/amp/celtics/video/wsc/teams/3ef5b6e1-9f04-27b0-7118-46e988b6ecf5
# 11
# https://www.nba.com/amp/nets/video/wsc/teams/5f2edcb1-0050-fb84-faa1-d619f8806d1d
# 37
# https://www.nba.com/amp/nets/video/wsc/teams/e14e8b23-786b-3e23-56d2-67f07a2d9b07
# 38
# https://www.nba.com/amp/nets/video/wsc/teams/e8c862c1-247d-0051-becd-4eb77f9d2495
# 39
# https://www.nba.com/amp/nets/video/wsc/teams/ed90fdd0-c52f-97ec-b7eb-54b0de4dcd96
# 40
# https://www.nba.com/amp/raptors/press-release/raptors-convert-boucher-to-two-way-contract
# 41
# https://www.nba.com/amp/raptors/schedule/download
# 42
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/01/02/1833571/1514920803459-nba-web-180102-demarsounddigital-1833571
# 43
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/01/03/1835489/1515001421508-nba-web-180103-vanvleetdigital-1835489
# 44
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/01/03/1835516/1515002558102-nba-web-180103-caseydigital-1835516
# 45
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/02/09/1915172/1518144329035-nba-web-180208-poeltlslamdigital-1915172
# 46
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/02/09/1915232/1518146186481-nba-web-180208-gamehildigital-1915232
# 47
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/02/09/1915375/1518149955505-nba-web-180208-vanvleetpostdigital-1915375
# 48
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/02/09/1916851/1518195447890-nba-web-180209-masai-presser-1916851
# 49
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/03/08/1973069/1520480306560-nba-web-180307-derozan-clutch-shot-1-1973069
# 50
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/03/08/1973079/1520480593614-nba-web-180307-derozan-clutch-dunk-v2-1973079
# 51
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/03/08/1973185/1520482521321-nba-web-180307-tor-det-game-highlights-1973185
# 52
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/03/08/1973217/1520483057446-nba-web-180307-casey-post-sound-1973217
# 53
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/03/08/1973258/1520483656213-nba-web-180307-vanvleet-post-sound-1973258
# 54
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/03/08/1973296/1520484047150-nba-web-180307-derozan-post-sound-1973296
# 55
# https://www.nba.com/amp/raptors/video/teams/raptors/2018/03/08/1973326/1520484415650-nba-web-180307-lowry-post-sound-1973326
# 56

# %%
import requests
import argparse
import time
import json
import gzip
import csv
import codecs
import io

from bs4 import BeautifulSoup
domain = "nba.com"
search_keywords = ["warriors","clippers","lakers","suns","kings"]
index_list = ["2019-04","2019-09","2019-13"]
def search_domain(domain):

    record_list = []
    
    print("[*] Trying target domain: %s" % domain)
    
    for index in index_list:
        
        print("[*] Trying index %s" % index)
        
        cc_url  = "http://index.commoncrawl.org/CC-MAIN-%s-index?" % index
        cc_url += "url=%s&matchType=domain&output=json" % domain
        
        response = requests.get(cc_url)
        
        if response.status_code == 200:
            
            records = response.content.splitlines()
            
            for record in records:
                record_list.append(json.loads(record))
            
            print("[*] Added %d results." % len(records))
            
    
    print("[*] Found a total of %d hits." % len(record_list))
    
    return record_list  

def download_page(record):

    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1

    # We'll get the file via HTTPS so we don't need to worry about S3 credentials
    # Getting the file on S3 is equivalent however - you can request a Range
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    
    # We can then use the Range header to ask for just this set of bytes
    resp = requests.get(prefix + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
    # The page is stored compressed (gzip) to save space
    # We can extract it using the GZIP library
    raw_data = io.BytesIO(resp.content)
    f = gzip.GzipFile(fileobj=raw_data)
    
    # What we have now is just the WARC response, formatted:
    data = f.read()

    response = ""
    htmlData = []
    #print(len(data))
    if len(data):
            htmlData = data.decode('UTF-8').strip().split("\r\n\r\n")
            if(len(htmlData)>2):
                response = htmlData[2]
                #print(fdg[0])
                #print(response)
    return response
count=0
weburlTest=[]
category = "news"
keywordtest = "/"+category+"/"
record_list = search_domain(domain)
index = open('pacific_scrawlData.txt', 'a+')
for record in record_list[:10000]:
    for idx in range(0,len(search_keywords)):
        #if(keywordtest.lower() in record['url']): 
            search_keyword = search_keywords[idx]
            keyword = "/"+search_keyword+"/"
            #print(keyword)
            if(keywordtest.lower() in record['url']):
                if(keyword.lower() in record['url']):
                    print(record['url'])
                    count+=1
                    print(count)
                    html_content = download_page(record)
                    soup = BeautifulSoup(html_content)
                    for p in soup.find_all("p", text=True):
                        rete = p.get_text()
                        rete = rete.replace('\n', '')
                        rete = rete.replace('\r\n', '')
                        rete = rete.replace('\\n','')
                        rete = rete.replace('\t','')
                        #print(rete)
                        index.write(rete)
                    index.write("\n")
# Out:
# [*] Trying target domain: nba.com
# [*] Trying index 2019-04
# [*] Added 13445 results.
# [*] Trying index 2019-09
# [*] Added 14007 results.
# [*] Trying index 2019-13
# [*] Added 14261 results.
# [*] Found a total of 41713 hits.
# https://www.nba.com/clippers/news/2018-summer-league-recap
# 1
# http://www.nba.com/clippers/news/breakingnews091109.html
# 2
# https://www.nba.com/clippers/news/breakingnews091109.html
# 3
# https://www.nba.com/clippers/news/breakingnews100204.html
# 4
# http://www.nba.com/clippers/news/breakingnews_100728.html
# 5
# https://www.nba.com/clippers/news/breakingnews_100728.html
# 6
# https://www.nba.com/clippers/news/brian_sieman.html
# 7
# http://www.nba.com/clippers/news/clippers-trade-evans-nets-120711.html
# 8
# https://www.nba.com/clippers/news/clippers-trade-evans-nets-120711.html
# 9
# http://www.nba.com/clippers/news/davis-being-team-fresh-energy
# 10
# https://www.nba.com/clippers/news/davis-being-team-fresh-energy
# 11
# http://www.nba.com/clippers/news/dunleavy_030711.html
# 12
# https://www.nba.com/clippers/news/dunleavy_030711.html
# 13
# http://www.nba.com/clippers/news/kaman_espnotl_080115.html
# 14
# https://www.nba.com/clippers/news/kaman_espnotl_080115.html
# 15
# https://www.nba.com/clippers/news/la-clippers-acquire-marcin-gortat
# 16
# https://www.nba.com/clippers/news/la-clippers-acquire-marcin-gortat?camefrom=LACHP
# 17
# http://www.nba.com/clippers/news/mailbag-redick-answers-fan-questions
# 18
# https://www.nba.com/clippers/news/mailbag-redick-answers-fan-questions
# 19
# https://www.nba.com/clippers/news/ralph_lawler.html
# 20
# http://www.nba.com/clippers/news/usa-basketball-announces-finalists-2012-olympic-team.html
# 21
# https://www.nba.com/clippers/news/usa-basketball-announces-finalists-2012-olympic-team.html
# 22

# %%
import requests
import argparse
import time
import json
import gzip
import csv
import codecs
import io

from bs4 import BeautifulSoup
domain = "www.nba.com/article/*"
search_keywords = ["mavericks","rockets","grizzlies","pelicans","spurs"]
index_list = ["2019-04","2019-09","2019-13"]
def search_domain(domain):

    record_list = []
    
    print("[*] Trying target domain: %s" % domain)
    
    for index in index_list:
        
        print("[*] Trying index %s" % index)
        
        cc_url  = "http://index.commoncrawl.org/CC-MAIN-%s-index?" % index
        cc_url += "url=%s&matchType=domain&output=json" % domain
        
        response = requests.get(cc_url)
        
        if response.status_code == 200:
            
            records = response.content.splitlines()
            
            for record in records:
                record_list.append(json.loads(record))
            
            print("[*] Added %d results." % len(records))
            
    
    print("[*] Found a total of %d hits." % len(record_list))
    
    return record_list  

def download_page(record):

    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1

    # We'll get the file via HTTPS so we don't need to worry about S3 credentials
    # Getting the file on S3 is equivalent however - you can request a Range
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    
    # We can then use the Range header to ask for just this set of bytes
    resp = requests.get(prefix + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
    # The page is stored compressed (gzip) to save space
    # We can extract it using the GZIP library
    raw_data = io.BytesIO(resp.content)
    f = gzip.GzipFile(fileobj=raw_data)
    
    # What we have now is just the WARC response, formatted:
    data = f.read()

    response = ""
    htmlData = []
    #print(len(data))
    if len(data):
            htmlData = data.decode('UTF-8').strip().split("\r\n\r\n")
            if(len(htmlData)>2):
                response = htmlData[2]
                #print(fdg[0])
                #print(response)
    return response
count=0
weburlTest=[]
category = "amp"
keywordtest = "/"+category+"/"
record_list = search_domain(domain)
index = open('southwest_scrawlData.txt', 'a+')
for record in record_list[:5000]:
    for idx in range(0,len(search_keywords)):
        #if(keywordtest.lower() in record['url']): 
            search_keyword = search_keywords[idx]
            keyword = "/"+search_keyword+"/"
            #print(keyword)
            if(keywordtest.lower() in record['url']):
                if(keyword.lower() in record['url']):
                    print(record['url'])
                    count+=1
                    print(count)
                    html_content = download_page(record)
                    soup = BeautifulSoup(html_content)
                    for p in soup.find_all("p", text=True):
                        rete = p.get_text()
                        rete = rete.replace('\n', '')
                        rete = rete.replace('\r\n', '')
                        rete = rete.replace('\\n','')
                        rete = rete.replace('\t','')
                        #print(rete)
                        index.write(rete)
                    index.write("\n")
# Out:
# [*] Trying target domain: www.nba.com/article/*
# [*] Trying index 2019-04
# [*] Added 13445 results.
# [*] Trying index 2019-09
# [*] Added 14007 results.
# [*] Trying index 2019-13
# [*] Added 14261 results.
# [*] Found a total of 41713 hits.
# https://www.nba.com/amp/grizzlies/video/gcm-alexis-all-access-methodist-healthcare-fitness-180201
# 1
# https://www.nba.com/amp/grizzlies/video/gcm-alexis-jarell-martin-1on1-180209
# 2
# https://www.nba.com/amp/grizzlies/video/gcm-alexis-jaren-jackson-1on1-181016
# 3
# https://www.nba.com/amp/grizzlies/video/gcm-alexis-morgan-postup-171222
# 4
# https://www.nba.com/amp/pelicans/video/teams/pelicans/2018/10/20/2302845/1540005306799-davispost101918-2302845
# 44
# https://www.nba.com/amp/pelicans/video/teams/pelicans/2018/10/20/2302854/1540005876222-miroticpost101918-2302854
# 45
# https://www.nba.com/amp/rockets/video/teams/rockets/2018/01/02/1833467/1514916620766-coach1218-1833467
# 46
# https://www.nba.com/amp/rockets/video/teams/rockets/2018/01/02/1833468/1514916637853-green1218-1833468
# 47
# https://www.nba.com/amp/rockets/video/teams/rockets/2018/03/06/1968707/1520351088041-attnbanhlclintep2final-1968707
# 48
# https://www.nba.com/amp/rockets/video/teams/rockets/2018/03/08/1973077/1520480583473-img5001-1973077
# 49
# https://www.nba.com/amp/rockets/video/teams/rockets/2018/03/08/1973182/1520482464473-img4640-1973182
# 50
# https://www.nba.com/amp/rockets/video/teams/rockets/2018/12/12/2376676/1544649078854-jh-2376676
# 51
# https://www.nba.com/amp/rockets/video/teams/rockets/2018/12/12/2376677/1544649080930-nene-2376677
# 52
# https://www.nba.com/amp/rockets/video/teams/rockets/2018/12/12/2376679/1544649114250-mda-2376679
# 53
# https://www.nba.com/amp/rockets/video/wsc/teams/006e32b6-c568-f07f-8003-8113f0fd720d
# 54
# https://www.nba.com/amp/rockets/video/wsc/teams/32d7124d-9b57-7587-e9c9-44e886d249a6
# 55
# https://www.nba.com/amp/rockets/video/wsc/teams/33070034-59c7-5e02-a875-ee90ee136d87
# 56
# https://www.nba.com/amp/rockets/video/wsc/teams/3ba6658e-7134-9e9c-cfd3-297887e20fcc
# 57
# https://www.nba.com/amp/rockets/video/wsc/teams/5ba429c8-ef19-1068-365d-14efe9c31a17
# 58
# https://www.nba.com/amp/rockets/video/wsc/teams/a4800981-e392-9aae-328f-64074a8faf6f
# 59
# https://www.nba.com/amp/rockets/video/wsc/teams/a7d248a7-bddc-b9cf-41be-1bfe103a2eb8
# 60
# https://www.nba.com/amp/rockets/video/wsc/teams/ce58c719-4654-0eb8-e17e-55aa92c0e4f0
# 61

# %%
import requests
import argparse
import time
import json
import gzip
import csv
import codecs
import io

from bs4 import BeautifulSoup
domain = "nba.com"
search_keywords = ["hawks","hornets","heat","magic","wizards"]
index_list = ["2019-04","2019-09","2019-13"]
def search_domain(domain):

    record_list = []
    
    print("[*] Trying target domain: %s" % domain)
    
    for index in index_list:
        
        print("[*] Trying index %s" % index)
        
        cc_url  = "http://index.commoncrawl.org/CC-MAIN-%s-index?" % index
        cc_url += "url=%s&matchType=domain&output=json" % domain
        
        response = requests.get(cc_url)
        
        if response.status_code == 200:
            
            records = response.content.splitlines()
            
            for record in records:
                record_list.append(json.loads(record))
            
            print("[*] Added %d results." % len(records))
            
    
    print("[*] Found a total of %d hits." % len(record_list))
    
    return record_list  

def download_page(record):

    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1

    # We'll get the file via HTTPS so we don't need to worry about S3 credentials
    # Getting the file on S3 is equivalent however - you can request a Range
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    
    # We can then use the Range header to ask for just this set of bytes
    resp = requests.get(prefix + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
    # The page is stored compressed (gzip) to save space
    # We can extract it using the GZIP library
    raw_data = io.BytesIO(resp.content)
    f = gzip.GzipFile(fileobj=raw_data)
    
    # What we have now is just the WARC response, formatted:
    data = f.read()

    response = ""
    fdg = []
    #print(len(data))
    if len(data):
            fdg = data.decode('UTF-8').strip().split("\r\n\r\n")
            if(len(fdg)>2):
                response = fdg[2]
                #print(fdg[0])
                #print(response)
    return response
count=0
weburlTest=[]
category = "amp"
keywordtest = "/"+category+"/"
record_list = search_domain(domain)
index = open('southeast_scrawlData.txt', 'w')
for record in record_list[:5000]:
    for idx in range(0,len(search_keywords)):
        #if(keywordtest.lower() in record['url']): 
            search_keyword = search_keywords[idx]
            keyword = "/"+search_keyword+"/"
            #print(keyword)
            if(keywordtest.lower() in record['url']):
                if(keyword.lower() in record['url']):
                    print(record['url'])
                    count+=1
                    print(count)
                    html_content = download_page(record)
                    soup = BeautifulSoup(html_content)
                    for p in soup.find_all("p", text=True):
                        rete = p.get_text()
                        rete = rete.replace('\n', '')
                        rete = rete.replace('\r\n', '')
                        rete = rete.replace('\\n','')
                        rete = rete.replace('\t','')
                        #print(rete)
                        index.write(rete)
                    index.write("\n")
# Out:
# [*] Trying target domain: nba.com
# [*] Trying index 2019-04
# [*] Added 13445 results.
# [*] Trying index 2019-09
# [*] Added 14007 results.
# [*] Trying index 2019-13
# [*] Added 14261 results.
# [*] Found a total of 41713 hits.
# https://www.nba.com/amp/hawks/black-fives-story-atlanta-municipal-auditorium
# 1
# https://www.nba.com/amp/hawks/collins-with-third-career-high-of-the-season-scores-thirty-against-nuggets
# 2
# https://www.nba.com/amp/hawks/couple-dating-swipe-right-night-married-arena-video
# 3
# https://www.nba.com/amp/hawks/deandre-bembry-notches-a-new-career-high-with-eighteen-points
# 4
# https://www.nba.com/amp/hawks/dennis-schroder-creates-magic-orlando-despite-loss
# 5
# https://www.nba.com/amp/hawks/hawks-keep-fast-pace-vs-raptors-highlight-video
# 6
# https://www.nba.com/amp/hawks/hawks-players-make-it-rain-in-philips-arena-cavaliers
# 7
# https://www.nba.com/amp/hawks/hawks-soar-fashion-thrilling-win-over-grizzlies
# 8
# https://www.nba.com/amp/hawks/kap-g-episodio-uno-rapper-heritage-college-park
# 9
# https://www.nba.com/amp/hawks/plays-of-the-week-collins-takes-flight
# 10
# https://www.nba.com/amp/hawks/plays-of-the-week-princes-game-winner
# 11
# https://www.nba.com/amp/hawks/time-lapse-philips-arena-transforms-six-events-seven-days
# 12
# https://www.nba.com/amp/hawks/trae-young-impresses-notches-double-double
# 13
# https://www.nba.com/amp/hawks/watch-top-17-plays-of-2017
# 14
# https://www.nba.com/amp/heat/community
# 15
# https://www.nba.com/amp/heat/video/dwyane-wade-post-sound-181212
# 16
# https://www.nba.com/amp/heat/video/erik-spoelstra-post-sound-181212
# 17
# https://www.nba.com/amp/heat/video/ko-3-181212
# 18
# https://www.nba.com/amp/hornets/video/teams/hornets/2018
# https://www.nba.com/amp/wizards/video/teams/wizards/2018/03/07/1970379/1520394992222-bealmorris0306-1970379
# 54
# https://www.nba.com/amp/wizards/video/teams/wizards/2018/03/07/1971361/1520439881190-wizheat-wizgirls-2-wizheat-2018-03-06-1971361
# 55
# https://www.nba.com/amp/wizards/video/teams/wizards/2018/03/07/1971821/1520454462043-20180228jrwizardscampv4-1971821
# 56
# https://www.nba.com/amp/wizards/video/teams/wizards/2018/03/07/1971845/1520455287039-brooks0307-1971845
# 57
# https://www.nba.com/amp/wizards/video/teams/wizards/2018/03/08/1974991/1520548332821-seqspecialolympicsunifiedgamefullv2-1974991
# 58

# %%
import requests
import argparse
import time
import json
import gzip
import csv
import codecs
import io

from bs4 import BeautifulSoup
domain = "nba.com"
search_keywords = ["bulls","cavaliers","pistons","pacers","bucks"]
index_list = ["2019-04","2019-09","2019-13"]
def search_domain(domain):

    record_list = []
    
    print("[*] Trying target domain: %s" % domain)
    
    for index in index_list:
        
        print("[*] Trying index %s" % index)
        
        cc_url  = "http://index.commoncrawl.org/CC-MAIN-%s-index?" % index
        cc_url += "url=%s&matchType=domain&output=json" % domain
        
        response = requests.get(cc_url)
        
        if response.status_code == 200:
            
            records = response.content.splitlines()
            
            for record in records:
                record_list.append(json.loads(record))
            
            print("[*] Added %d results." % len(records))
            
    
    print("[*] Found a total of %d hits." % len(record_list))
    
    return record_list  

def download_page(record):

    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1

    # We'll get the file via HTTPS so we don't need to worry about S3 credentials
    # Getting the file on S3 is equivalent however - you can request a Range
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    
    # We can then use the Range header to ask for just this set of bytes
    resp = requests.get(prefix + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
    # The page is stored compressed (gzip) to save space
    # We can extract it using the GZIP library
    raw_data = io.BytesIO(resp.content)
    f = gzip.GzipFile(fileobj=raw_data)
    
    # What we have now is just the WARC response, formatted:
    data = f.read()

    response = ""
    fdg = []
    #print(len(data))
    if len(data):
            fdg = data.decode('UTF-8').strip().split("\r\n\r\n")
            if(len(fdg)>2):
                response = fdg[2]
                #print(fdg[0])
                #print(response)
    return response
count=0
weburlTest=[]
category = "news"
keywordtest = "/"+category+"/"
record_list = search_domain(domain)
index = open('central_scrawlData.txt', 'w')
for record in record_list[:6000]:
    for idx in range(0,len(search_keywords)):
        #if(keywordtest.lower() in record['url']): 
            search_keyword = search_keywords[idx]
            keyword = "/"+search_keyword+"/"
            #print(keyword)
            if(keywordtest.lower() in record['url']):
                if(keyword.lower() in record['url']):
                    print(record['url'])
                    count+=1
                    print(count)
                    html_content = download_page(record)
                    soup = BeautifulSoup(html_content)
                    for p in soup.find_all("p", text=True):
                        rete = p.get_text()
                        #print(rete)
                        index.write(rete)
                    index.write("\n")
# Out:
# [*] Trying target domain: nba.com
# [*] Trying index 2019-04
# [*] Added 13445 results.
# [*] Trying index 2019-09
# [*] Added 14007 results.
# [*] Trying index 2019-13
# http://www.nba.com/bucks/news/three_team_trade_080813.html
# 31
# https://www.nba.com/bucks/news/three_team_trade_080813.html
# 32
# https://www.nba.com/bucks/news/usa-mens-world-cup-qualifying-team-announced-september-games
# 33
# https://www.nba.com/bucks/news/wisconsin-entertainment-and-sports-center-hold-job-fair-june-20
# 34
# https://www.nba.com/bucks/news/wisconsin-herd-acquires-returning-player-rights-shevon-thompson
# 35
# https://www.nba.com/bucks/news/wisconsin-herd-acquires-travis-trice-three-team-deal
# 36
# http://www.nba.com/bucks/news/wisconsin-herd-adds-nba-veteran-shannon-brown
# 37
# https://www.nba.com/bucks/news/wisconsin-herd-adds-nba-veteran-shannon-brown
# 38
# http://www.nba.com/bucks/news/Yi_Signed_070829.html
# 39
# https://www.nba.com/bucks/news/Yi_Signed_070829.html
# 40

# %%
import requests
import argparse
import time
import json
import gzip
import csv
import codecs
import io

from bs4 import BeautifulSoup
domain = "nba.com"
search_keywords = ["nba"]
index_list = ["2019-04","2019-09","2019-13"]
def search_domain(domain):

    record_list = []
    
    print("[*] Trying target domain: %s" % domain)
    
    for index in index_list:
        
        print("[*] Trying index %s" % index)
        
        cc_url  = "http://index.commoncrawl.org/CC-MAIN-%s-index?" % index
        cc_url += "url=%s&matchType=domain&output=json" % domain
        
        response = requests.get(cc_url)
        
        if response.status_code == 200:
            
            records = response.content.splitlines()
            
            for record in records:
                record_list.append(json.loads(record))
            
            print("[*] Added %d results." % len(records))
            
    
    print("[*] Found a total of %d hits." % len(record_list))
    
    return record_list  

def download_page(record):

    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1

    # We'll get the file via HTTPS so we don't need to worry about S3 credentials
    # Getting the file on S3 is equivalent however - you can request a Range
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    
    # We can then use the Range header to ask for just this set of bytes
    resp = requests.get(prefix + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
    # The page is stored compressed (gzip) to save space
    # We can extract it using the GZIP library
    raw_data = io.BytesIO(resp.content)
    f = gzip.GzipFile(fileobj=raw_data)
    
    # What we have now is just the WARC response, formatted:
    data = f.read()

    response = ""
    fdg = []
    #print(len(data))
    if len(data):
            fdg = data.decode('UTF-8').strip().split("\r\n\r\n")
            if(len(fdg)>2):
                response = fdg[2]
                #print(fdg[0])
                #print(response)
    return response
count=0
weburlTest=[]
category = "news"
keywordtest = "/"+category+"/"
record_list = search_domain(domain)
index = open('nba_scrawlData.txt', 'w')
for record in record_list:
    for idx in range(0,len(search_keywords)):
        #if(keywordtest.lower() in record['url']): 
            search_keyword = search_keywords[idx]
            keyword = "/"+search_keyword+"/"
            #print(keyword)
            if(keyword.lower() in record['url']):
                #if(keyword.lower() in record['url']):
                    print(record['url'])
                    count+=1
                    print(count)
                    html_content = download_page(record)
                    soup = BeautifulSoup(html_content)
                    for p in soup.find_all("p", text=True):
                        rete = p.get_text()
                        #print(rete)
                        index.write(rete)
                    index.write("\n")
